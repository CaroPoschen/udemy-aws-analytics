# %%
print('Hello World')
# Out:
# Hello World

# %%
df = spark. \
    read. \
    parquet('s3://itv-emr-studio/itv-emr-studio/prod/raw/ghactivity/')
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df.printSchema()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- actor: struct (nullable = true)
#  |    |-- avatar_url: string (nullable = true)
#  |    |-- display_login: string (nullable = true)
#  |    |-- gravatar_id: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- login: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- org: struct (nullable = true)
#  |    |-- avatar_url: string (nullable = true)
#  |    |-- gravatar_id: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- login: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- payload: struct (nullable = true)
#  |    |-- action: string (nullable = true)
#  |    |-- before: string (nullable = true)
#  |    |-- comment: struct (nullable = true)
# ...

# %%
df.select('created_at').show(20, truncate=False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------------+
# |created_at          |
# +--------------------+
# |2021-01-13T15:00:00Z|
# |2021-01-13T06:12:05Z|
# |2021-01-13T15:00:00Z|
# |2021-01-13T06:12:05Z|
# |2021-01-13T15:00:00Z|
# |2021-01-13T06:12:05Z|
# |2021-01-13T15:00:00Z|
# |2021-01-13T06:12:06Z|
# |2021-01-13T15:00:00Z|
# |2021-01-13T06:12:06Z|
# |2021-01-13T15:00:00Z|
# |2021-01-13T06:12:06Z|
# |2021-01-13T15:00:00Z|
# |2021-01-13T06:12:06Z|
# |2021-01-13T15:00:00Z|
# |2021-01-13T06:12:06Z|
# |2021-01-13T15:00:00Z|
# |2021-01-13T06:12:06Z|
# |2021-01-13T15:00:00Z|
# |2021-01-13T06:12:06Z|
# +--------------------+
# only showing top 20 rows

# %%
df.show()

# %%
df.count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 8339829

# %%
df.filter("substr(created_at, 1, 10) == '2021-01-13'").show()

# %%
df.filter("substr(created_at, 1, 10) == '2021-01-13'").count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 2829111

# %%
df.filter("substr(created_at, 1, 10) == '2021-01-14'").count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 2857818

# %%
df.filter("substr(created_at, 1, 10) == '2021-01-15'").count()

# %%
from pyspark.sql.functions import count, expr, lit
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df. \
    groupBy(expr('substr(created_at, 1, 10)').alias('created_date')). \
    agg(count(lit("*")).alias("activity_count")). \
    show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +------------+--------------+
# |created_date|activity_count|
# +------------+--------------+
# |  2021-01-13|       2829111|
# +------------+--------------+
